# %%
import pytesseract
from PIL import Image
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

# %%
# !pip install pymupdf pytesseract pillow ollama langchain sentence-transformers faiss-cpu numpy
# Out:
# Requirement already satisfied: pymupdf in c:\users\aryan pund\anaconda3\lib\site-packages (1.25.3)
# Requirement already satisfied: pytesseract in c:\users\aryan pund\anaconda3\lib\site-packages (0.3.13)
# Requirement already satisfied: pillow in c:\users\aryan pund\anaconda3\lib\site-packages (10.4.0)
# Requirement already satisfied: ollama in c:\users\aryan pund\anaconda3\lib\site-packages (0.4.7)
# Requirement already satisfied: langchain in c:\users\aryan pund\anaconda3\lib\site-packages (0.3.18)
# Requirement already satisfied: sentence-transformers in c:\users\aryan pund\anaconda3\lib\site-packages (3.4.1)
# Requirement already satisfied: faiss-cpu in c:\users\aryan pund\anaconda3\lib\site-packages (1.10.0)
# Requirement already satisfied: numpy in c:\users\aryan pund\anaconda3\lib\site-packages (1.26.4)
# Requirement already satisfied: packaging>=21.3 in c:\users\aryan pund\anaconda3\lib\site-packages (from pytesseract) (24.1)
# Requirement already satisfied: httpx<0.29,>=0.27 in c:\users\aryan pund\anaconda3\lib\site-packages (from ollama) (0.27.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in c:\users\aryan pund\anaconda3\lib\site-packages (from ollama) (2.10.6)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.34 in c:\users\aryan pund\anaconda3\lib\site-packages (from langchain) (0.3.35)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.6 in c:\users\aryan pund\anaconda3\lib\site-packages (from langchain) (0.3.6)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in c:\users\aryan pund\anaconda3\lib\site-packages (from langchain) (0.3.8)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\aryan pund\anaconda3\lib\site-packages (from langchain) (2.0.34)
# Requirement already satisfied: requests<3,>=2 in c:\users\aryan pund\anaconda3\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\aryan pund\anaconda3\lib\site-packages (from langchain) (6.0.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\aryan pund\anaconda3\lib\site-packages (from langchain) (3.10.5)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\aryan pund\anaconda3\lib\site-packages (from langchain) (8.2.3)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\aryan pund\anaconda3\lib\site-packages (from sentence-transformers) (4.49.0)
# Requirement already satisfied: tqdm in c:\users\aryan pund\anaconda3\lib\site-packages (from sentence-transformers) (4.66.5)
# Requirement already satisfied: torch>=1.11.0 in c:\users\aryan pund\anaconda3\lib\site-packages (from sentence-transformers) (2.6.0)
# Requirement already satisfied: scikit-learn in c:\users\aryan pund\anaconda3\lib\site-packages (from sentence-transformers) (1.5.1)
# Requirement already satisfied: scipy in c:\users\aryan pund\anaconda3\lib\site-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\aryan pund\anaconda3\lib\site-packages (from sentence-transformers) (0.28.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\aryan pund\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\aryan pund\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\aryan pund\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\aryan pund\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\aryan pund\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\aryan pund\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.11.0)
# Requirement already satisfied: anyio in c:\users\aryan pund\anaconda3\lib\site-packages (from httpx<0.29,>=0.27->ollama) (4.2.0)
# Requirement already satisfied: certifi in c:\users\aryan pund\anaconda3\lib\site-packages (from httpx<0.29,>=0.27->ollama) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\aryan pund\anaconda3\lib\site-packages (from httpx<0.29,>=0.27->ollama) (1.0.2)
# Requirement already satisfied: idna in c:\users\aryan pund\anaconda3\lib\site-packages (from httpx<0.29,>=0.27->ollama) (3.7)
# Requirement already satisfied: sniffio in c:\users\aryan pund\anaconda3\lib\site-packages (from httpx<0.29,>=0.27->ollama) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\aryan pund\anaconda3\lib\site-packages (from httpcore==1.*->httpx<0.29,>=0.27->ollama) (0.14.0)
# Requirement already satisfied: filelock in c:\users\aryan pund\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\aryan pund\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\aryan pund\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (4.12.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\aryan pund\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.34->langchain) (1.33)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\aryan pund\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\aryan pund\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\aryan pund\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\aryan pund\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.9.0->ollama) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\aryan pund\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.9.0->ollama) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aryan pund\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aryan pund\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2.2.3)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\aryan pund\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.1)
# Requirement already satisfied: networkx in c:\users\aryan pund\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in c:\users\aryan pund\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\aryan pund\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (75.1.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\aryan pund\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\aryan pund\anaconda3\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\aryan pund\anaconda3\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\aryan pund\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.9.11)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\aryan pund\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\aryan pund\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\aryan pund\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\aryan pund\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\aryan pund\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.34->langchain) (2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\aryan pund\anaconda3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.3)

# %%
import fitz
import pytesseract
from PIL import Image
import io
from langchain.text_splitter import RecursiveCharacterTextSplitter
from sentence_transformers import SentenceTransformer
import faiss
import numpy as np
import re
import ollama  

def extract_text_from_pdf(pdf_path):
    text = ""
    doc = fitz.open(pdf_path)
    for page_num in range(len(doc)):
        page = doc.load_page(page_num)
        pix = page.get_pixmap()
        img = Image.open(io.BytesIO(pix.tobytes()))
        if not page.get_text("text"):
            text += pytesseract.image_to_string(img, lang='eng')
        else:
            text += page.get_text("text")
    return text

def clean_text(text):
    text = re.sub(r'\s+', ' ', text)  # Remove extra whitespace
    text = re.sub(r'[^\w\s]', '', text)  # Remove special characters
    return text.strip()

def chunk_text(text, chunk_size=1000, chunk_overlap=200):
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=chunk_size,
        chunk_overlap=chunk_overlap,
        length_function=len
    )
    chunks = text_splitter.split_text(text)
    return chunks

class EmbeddingModel:
    def __init__(self, model_name="paraphrase-multilingual-MiniLM-L12-v2"):
        self.model = SentenceTransformer(model_name)

    def generate_embeddings(self, texts):
        return self.model.encode(texts)

class FAISSVectorDB:
    def __init__(self, embedding_model, dimension=384):
        self.embedding_model = embedding_model
        self.dimension = dimension
        self.index = faiss.IndexFlatL2(dimension)

    def add_documents(self, chunks):
        embeddings = self.embedding_model.generate_embeddings(chunks)
        self.index.add(np.array(embeddings).astype('float32'))

    def search(self, query, top_k=5):
        query_embedding = self.embedding_model.generate_embeddings([query])
        distances, indices = self.index.search(np.array(query_embedding).astype('float32'), top_k)
        return indices, distances

def generate_text_with_ollama(query, context):
    """
    Generate a response using Ollama's language model.
    """
    prompt = f"""You are a highly skilled document analyst. Your task is to generate a precise, well-structured response 
    to the given query using ONLY the provided context. Ensure that your answer is clear, comprehensive, and logically 
    organized. Where relevant, include key themes, supporting evidence, and well-defined sections with bullet points 
    for better readability.

    Query: {query}
    Context: {context}

    Response:"""
    
    response = ollama.generate(
        model='llama3.2',  # Use the desired Ollama model
        prompt=prompt,
        options={
            'temperature': 0.3,
            'num_predict': 1500,
            'top_k': 50,
            'top_p': 0.9
        }
    )
    return response['response']

if __name__ == "__main__":
    pdf_path = r"C:\Users\ARYAN PUND\Desktop\Multilingual\sample_pdfs\en\Reboot_Leadership_and_the_Art_of.pdf"
    extracted_text = extract_text_from_pdf(pdf_path)
    print("Text extracted from PDF.")

    cleaned_text = clean_text(extracted_text)
    chunks = chunk_text(cleaned_text)
    print(f"Number of chunks: {len(chunks)}")

    embedding_model = EmbeddingModel()
    vector_db = FAISSVectorDB(embedding_model)
    vector_db.add_documents(chunks)
    print("Embeddings generated and stored in FAISS.")

    queries = [
        "Summarize the document's key themes, major ideas, and underlying messages in detail.",
        "Examine the protagonist’s journey, highlighting their struggles, transformations, and key turning points.",
        "Discuss the document’s core message and its significance in today's social and cultural context.",
        "Outline the major events in the narrative and analyze their role in shaping the story’s progression.",
        "Explore the protagonist’s character growth, including emotional, intellectual, and moral developments.",
    ]

    for query in queries:
        print(f"\nQuery: {query}")
        indices, distances = vector_db.search(query, top_k=3)
        context = "\n\n".join([chunks[idx] for idx in indices[0]])
        response = generate_text_with_ollama(query, context)
        print(f"Generated Response:\n{response}")
        print("―" * 60)
# Out:
# Text extracted from PDF.
# Number of chunks: 459
# Embeddings generated and stored in FAISS.
#
# Query: Summarize the document's key themes, major ideas, and underlying messages in detail.
# Generated Response:
# **Document Analysis: Key Themes, Major Ideas, and Underlying Messages**
#
# The provided document appears to be an email or introduction to a book written by the author. The content revolves around the theme of finding direction and meaning in one's personal, professional, and practical goals. The underlying messages are centered around the importance of self-awareness, growth, and resilience.
#
# **Key Themes:**
#
# • **The Search for Meaning**: The document highlights the desire to define a meaningful next chapter that aligns with personal, professional, and practical goals.
# • **Self-Awareness and Growth**: The author emphasizes the need to understand one's relationship with money, work, and life to achieve growth and resilience.
# • **Resilience and Equanimity**: The book explores heartbreak, resilience, and the path to equanimity, suggesting that this is a crucial aspect of personal growth.
#
# **Major Ideas:**
#
# • **The Power of Inquiry**: The author aims to provide an experience that allows readers to challenge their assumptions, grow, and think critically about the structures of their life.
# • **Unconscious Patterns and Community**: The book seeks to unmask unconscious patterns and enhance community, which is essential for healing and personal growth.
# • **Disrupting Protected Narratives**: A well-asked question can disrupt protected narratives that have shielded us from growth and change.
#
# **Underlying Messages:**
#
# • **The Importance of Self-Awareness**: The document emphasizes the need to understand one's relationship with money, work, and life to achieve personal growth and resilience.
# • **Growth and Resilience as Essential for Happiness**: The author suggests that growth, resilience, and equanimity are crucial for living a happy and fulfilling life.
# • **The Need for Community and Support**: The book highlights the importance of community and support in facilitating personal growth and healing.
#
# **Author's Intentions:**
#
# • **Provide a Coaching or Boot Camp Experience**: The author aims to provide an experience that allows readers to challenge their assumptions, grow, and think critically about their life.
# • **Tap into Unconscious Mind**: The book seeks to tap into the unconscious mind using tools of inquiry to enhance personal growth and community.
#
# **Book Structure:**
#
# The document appears to be a foreword or introduction to a book with the following chapters:
#
# * Chapter 1: Exploring one's relationship with money and work
# * Chapter 8: Heartbreak, resilience, and equanimity
# * Chapter 9: Leadership and growing up
# * Afterword
# * Author's Note
# * Acknowledgments
# * About the Author
# * Endorsements
# * Copyright
# * Foreword
#
# Overall, the document presents a compelling narrative that emphasizes the importance of self-awareness, growth, and resilience in achieving personal fulfillment.
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
#
# Query: Examine the protagonist’s journey, highlighting their struggles, transformations, and key turning points.
# Generated Response:
# **The Protagonist's Journey: A Path to Wholeness and Leadership**
#
# The protagonist's journey, as described in the provided context, is one of self-discovery, transformation, and growth. The individual's struggles, transformations, and key turning points are highlighted throughout their life, from adolescence to adulthood.
#
# **Early Struggles and Romanticization of Self-Destruction**
#
# As a teenager, the protagonist found solace in the romanticized notion of the writer who destroys their work or the painter who self-destructs. This fascination with self-destruction was likely a coping mechanism for dealing with inner turmoil.
#
# **Mid-Life Crisis and Inner Voice Mapping**
#
# In their thirties, the protagonist began to map out the web of critical inner voices and persistent wishes for love, safety, and belonging. They started to recognize how these internal conflicts were projected into the world through relationships, work, and other aspects of life.
#
# **Aha Moment: The Inner Critic's Purpose**
#
# It wasn't until their fifties that the protagonist realized the critical voice was meant to soothe and protect them from humiliation, shame, and being seen as an impostor. This understanding marked a significant turning point in their journey towards wholeness and leadership.
#
# **Key Turning Points: Embracing Vulnerability and Courage**
#
# The protagonist's journey is characterized by several key turning points:
#
# • **Embracing vulnerability**: The protagonist has come to understand the importance of being vulnerable, sharing themselves, and modeling courageous leadership.
# • **Facing pain head-on**: They have learned to confront their inner demons and face their pain with heart, rather than avoiding or suppressing it.
# • **Developing a healthier sense of self**: Through their journey, the protagonist has developed a more compassionate and whole understanding of themselves, which is essential for effective leadership.
#
# **Inspiration and Impact**
#
# The book "Reboot" by Jerry Colonna has inspired many readers to open up and be more vulnerable. The author's courage, leadership, and insight have made a significant impact on those who have read the book, including:
#
# • **Congressman Tim Ryan**: Who has stated that the book has inspired him to open up more and be more authentic.
# • **Bijan Sabet**: Co-founder and general partner of Spark Capital, who sees the book as offering a unique perspective on leadership and humanity.
# • **Isaac Oates**: CEO of Justworks, who praises the book for its ability to inspire leaders to become better humans.
#
# **Conclusion**
#
# The protagonist's journey is one of transformation and growth, marked by struggles, turning points, and key insights. Through their story, we see the importance of embracing vulnerability, facing pain head-on, and developing a healthier sense of self. "Reboot" has inspired many readers to take this path, leading to a more compassionate and whole understanding of themselves and others.
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
#
# Query: Discuss the document’s core message and its significance in today's social and cultural context.
# Generated Response:
# **Core Message Analysis**
#
# The core message of the document, as revealed through its context, is centered around the importance of self-awareness, personal growth, and finding meaning in one's life. The author aims to guide readers on a journey of introspection, using tools of inquiry that tap into their unconscious mind, to unmask long-held patterns and enhance their sense of community.
#
# **Key Themes:**
#
# • **Personal Growth**: The document emphasizes the need for individuals to confront and challenge their habitual patterns, leading to personal growth and self-awareness.
# • **Self-Discovery**: Through the use of tools of inquiry, readers are encouraged to explore their relationship with money, work, and other aspects of their life, leading to a deeper understanding of themselves.
# • **Community and Connection**: The author highlights the significance of community and connection in healing and finding meaning in life.
# • **Challenging Societal Expectations**: The document critiques societal expectations that prioritize material success and conformity over personal growth and well-being.
#
# **Significance in Today's Social and Cultural Context:**
#
# In today's fast-paced, consumerist society, where individuals are often encouraged to pursue material success at all costs, the core message of this document is particularly relevant. The author's emphasis on self-awareness, personal growth, and community highlights the need for individuals to re-evaluate their priorities and seek a more meaningful and fulfilling life.
#
# **Supporting Evidence:**
#
# • **The author's personal story**: Jerry's experience with the book "Faith" and his journey towards finding meaning in life serve as a powerful example of the importance of self-awareness and personal growth.
# • **The use of rhetorical questions**: The document's use of rhetorical questions, such as "How did my relationship to money first get formed?" and "What was the belief system around money and work that I grew up with?", encourages readers to reflect on their own experiences and challenge their assumptions.
#
# **Conclusion:**
#
# The core message of this document is a powerful call to action, urging individuals to embark on a journey of self-discovery and personal growth. By challenging societal expectations and prioritizing community and connection, readers can find meaning in life and create a more fulfilling and purpose-driven existence.
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
#
# Query: Outline the major events in the narrative and analyze their role in shaping the story’s progression.
# Generated Response:
# **Major Events in the Narrative and Their Role in Shaping the Story's Progression**
#
# The narrative presented in Chapter 8, "Heartbreak Resilience and the Path to Equanimity," is a personal and introspective journey of self-discovery and growth. The story is divided into several key events that shape the protagonist's progression towards equanimity.
#
# **I. Early Struggles with Inner Voices**
#
# * The protagonist reflects on their inner voices, which they initially saw as critical and negative (e.g., "the ones whispering that we are no good less than a fake").
# * These inner voices were perceived as protective mechanisms, shielding the individual from humiliation and shame.
#
# **II. Realization of Inner Voices' True Purpose**
#
# * The protagonist comes to understand that these inner voices are actually meant to soothe and keep them safe.
# * This realization marks a turning point in their journey, shifting their perspective on their inner voices.
#
# **III. The Importance of Self-Discovery**
#
# * The protagonist emphasizes the need to go inward and explore one's own story (as advised by Pádraig Ó Tuama).
# * They acknowledge that this process can be challenging, particularly when faced with the pressure to perform or meet expectations.
#
# **IV. The Power of Vulnerability and Impermanence**
#
# * The protagonist shares their friend Chad's story, highlighting the importance of embracing change and impermanence.
# * This narrative serves as a reminder that loss and vulnerability can be transformative experiences that allow individuals to grow and discover their true selves.
#
# **V. The Quest for Authenticity and Self-Acceptance**
#
# * The protagonist reflects on their own journey towards self-acceptance, acknowledging the need to "bring forth not only what is in you but the whole of you."
# * This pursuit of authenticity is a recurring theme throughout the narrative, emphasizing the importance of embracing one's true nature.
#
# **Key Themes and Supporting Evidence:**
#
# * **The Power of Self-Awareness**: The protagonist's journey highlights the significance of understanding one's inner voices and their role in shaping one's identity.
# * **Vulnerability as a Catalyst for Growth**: The narrative demonstrates how vulnerability, impermanence, and loss can be transformative experiences that facilitate personal growth and self-discovery.
# * **The Importance of Authenticity**: The protagonist's quest for authenticity serves as a reminder that embracing one's true nature is essential for living a fulfilling life.
#
# **Conclusion:**
#
# The major events in the narrative presented in Chapter 8 form a cohesive arc that explores the complexities of human identity, growth, and self-discovery. By examining these key events and themes, we can gain insight into the importance of self-awareness, vulnerability, and authenticity in shaping our personal narratives and fostering equanimity.
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
#
# Query: Explore the protagonist’s character growth, including emotional, intellectual, and moral developments.
# Generated Response:
# **Character Growth: A Journey of Self-Discovery**
#
# The protagonist's character growth is a multifaceted and transformative journey, marked by significant emotional, intellectual, and moral developments. This response will explore the key themes and stages of this growth, highlighting the protagonist's evolution from adolescence to adulthood.
#
# **Adolescence (Teenage Years)**
#
# * The protagonist develops a romanticized view of creatives who struggle with self-doubt, seeing them as noble and admirable.
# * This fascination stems from an idealized perception of artistic expression as a means of authentic self-expression.
#
# **Young Adulthood (Thirties)**
#
# * The protagonist begins to map out their inner voices and conflicts, recognizing the interconnectedness of personal relationships, work, and creative pursuits.
# * They start to see how their inner struggles are reflected in the world around them, leading to a deeper understanding of themselves and others.
#
# **Midlife Crisis (Fifties)**
#
# * The protagonist comes to realize that their critical inner voices, which once seemed like enemies, are actually meant to protect them from humiliation and shame.
# * They understand that these voices are a natural part of the growth process, allowing them to navigate challenges and develop resilience.
#
# **Key Themes**
#
# * **Self-Awareness**: The protagonist's journey is marked by increasing self-awareness, as they learn to recognize their inner voices, conflicts, and motivations.
# * **Growth Mindset**: They adopt a growth mindset, embracing challenges and viewing failures as opportunities for growth and learning.
# * **Compassion and Empathy**: Through the writings of Pema Chödrön, Parker Palmer, and Sharon Salzberg, the protagonist develops compassion and empathy for themselves and others.
#
# **Intellectual Developments**
#
# * The protagonist begins to see the world through a more nuanced lens, recognizing the interconnectedness of personal relationships, work, and creative pursuits.
# * They develop a deeper understanding of the importance of radical inquiry and the role of leadership as a journey into adulthood.
#
# **Emotional Developments**
#
# * The protagonist learns to navigate their emotions, developing resilience in the face of challenges and setbacks.
# * They cultivate compassion, empathy, and kindness towards themselves and others, leading to a more authentic and meaningful life.
#
# **Moral Developments**
#
# * The protagonist develops a stronger sense of moral compass, recognizing the importance of treating all beings with graciousness and respect.
# * They learn to approach leadership as a true adventure of growth, embracing challenges and viewing failures as opportunities for refinement and renewal.
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
